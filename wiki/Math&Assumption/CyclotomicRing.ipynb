# %%
k = 3
d = 2^k
q = 17

# %%
Rq.<X> = (R := Integers(q)['x']).quotient(R.gen()^d + 1)

# %%
Rq
# Out:
# Univariate Quotient Polynomial Ring in X over Ring of integers modulo 17 with modulus x^8 + 1
